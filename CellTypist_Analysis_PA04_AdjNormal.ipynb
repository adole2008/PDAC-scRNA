# %% [markdown]
# # Using CellTypist for cell type classification
# This notebook showcases the cell type classification for scRNA-seq query data by retrieving the most likely cell type labels from the built-in CellTypist models.

# %% [markdown]
# ## Install CellTypist

# %%
import sys
import subprocess
import warnings

# Suppress specific warnings
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
warnings.filterwarnings("ignore", category=NumbaDeprecationWarning)
warnings.filterwarnings("ignore", category=NumbaPendingDeprecationWarning)

# List of required packages
required_packages = [
    "anndata",
    "scanpy",
    "besca",
    "matplotlib",
    "pandas",
    "celltypist"
]

# Install packages quietly
for package in required_packages:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", package, "--quiet"],
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL
    )

# %%
# %%capture --no-display
import anndata
import scanpy as sc
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
import besca
import matplotlib.pyplot as plt
import pandas as pd
from functools import reduce
import operator
import celltypist
from celltypist import models

# %% [markdown]
# ## Load a scRNA-seq dataset .h5ad file

# %%
##  REPLACE <SAMPLE MATRIX FILE> with the filename of your matrix
adata = sc.read_h5ad('datasets/PA04_AdjNormal.h5ad')
adata.obs
# Out:
#                                                  patient  n_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1  PA04_AdjNormal     1404
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1  PA04_AdjNormal     4265
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1  PA04_AdjNormal     1621
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1  PA04_AdjNormal     1174
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1  PA04_AdjNormal     1346
# ...                                                  ...      ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1  PA04_AdjNormal     1161
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1  PA04_AdjNormal     1557
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1  PA04_AdjNormal     1471
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1  PA04_AdjNormal     1356
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1  PA04_AdjNormal     1107
#
#                                           n_genes_by_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1               1404
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1               4265
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1               1621
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1               1174
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1               1346
# ...                                                     ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1               1161
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1               1557
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1               1471
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1               1356
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1               1107
#
#                                           log1p_n_genes_by_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                 7.247793
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                 8.358432
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                 7.391415
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                 7.069023
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                 7.205635
# ...                                                           ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                 7.057898
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                 7.351158
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                 7.294377
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                 7.213032
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                 7.010312
#
#                                           total_counts  log1p_total_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1        2724.0            7.910223
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1       16713.0            9.724002
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1        3903.0            8.269757
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1        2438.0            7.799344
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1        3113.0            8.043663
# ...                                                ...                 ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1        2197.0            7.695303
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1        4046.0            8.305731
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1        3433.0            8.141481
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1        2836.0            7.950502
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1        2141.0            7.669495
#
#                                           pct_counts_in_top_50_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                   29.405286
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                   34.045354
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                   36.100436
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                   34.126333
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                   38.997751
# ...                                                              ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                   32.817478
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                   40.434998
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                   36.061754
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                   33.921016
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                   33.395610
#
#                                           pct_counts_in_top_100_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    38.362702
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    43.020403
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    45.785293
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    44.134537
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    47.414070
# ...                                                               ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    42.239417
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    49.728127
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    45.674337
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    42.806770
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    43.063989
#
#                                           pct_counts_in_top_200_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    49.118943
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    51.594567
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    55.649500
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    55.168171
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    57.115323
# ...                                                               ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    52.662722
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    58.897677
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    55.840373
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    53.173484
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    53.946754
#
#                                           pct_counts_in_top_500_genes  ...  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    66.813510  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    63.232214  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    71.278504  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    72.354389  ...
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    72.823643  ...
# ...                                                               ...  ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    69.913518  ...
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    73.875433  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    71.715701  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    69.816643  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    71.648762  ...
#
#                                           log1p_total_counts_mt  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1               4.584968
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1               6.401917
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1               4.962845
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1               4.317488
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1               3.951244
# ...                                                         ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1               4.007333
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1               4.532599
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1               4.094345
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1               3.871201
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1               4.727388
#
#                                           pct_counts_mt  total_counts_ribo  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1       3.560940                0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1       3.601987                0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1       3.638227                0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1       3.035275                0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1       1.638291                0.0
# ...                                                 ...                ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1       2.457897                0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1       2.273851                0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1       1.718614                0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1       1.657264                0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1       5.231201                0.0
#
#                                           log1p_total_counts_ribo  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                      0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                      0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                      0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                      0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                      0.0
# ...                                                           ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                      0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                      0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                      0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                      0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                      0.0
#
#                                           pct_counts_ribo  total_counts_hb  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1              0.0              0.0
# ...                                                   ...              ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1              0.0              0.0
#
#                                           log1p_total_counts_hb  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    0.0
# ...                                                         ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    0.0
#
#                                           pct_counts_hb  doublet_score  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1            0.0       0.030018
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1            0.0       0.035706
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1            0.0       0.024561
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1            0.0       0.025276
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1            0.0       0.010101
# ...                                                 ...            ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1            0.0       0.042654
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1            0.0       0.019193
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1            0.0       0.030453
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1            0.0       0.031341
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1            0.0       0.010470
#
#                                           predicted_doublet
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1              False
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1              False
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1              False
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1              False
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1              False
# ...                                                     ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1              False
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1              False
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1              False
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1              False
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1              False
#
# [10732 rows x 21 columns]

# %% [markdown]
# ## Assign cell type labels using a CellTypist built-in model
# In this section, we show the procedure of transferring cell type labels from a custom model to the query dataset.

# %%
## REPLACE <YOUR MODEL FILENAME> with the PKL file you made
custom_model = models.Model.load(model = 'UCSC_human_pancreas_model.pkl')

# %% [markdown]
# Show the built-in model meta information:

# %%
custom_model
# Out:
# CellTypist model with 21 cell types and 51863 features
#     date: 2025-08-10 11:08:01.514089
#     cell types: B cell, Mast cell, ..., t cell
#     features: WASH7P, MIR6859-1, ..., MT-TP

# %% [markdown]
# #### This model contains 15 cell states.

# %%
custom_model.cell_types
# Out:
# array(['B cell', 'Mast cell', 'NK cell', 'T cell', 'b cell',
#        'endothelial cell', 'fibroblast', 'mast cell', 'myeloid cell',
#        'pancreatic acinar cell', 'pancreatic acing cell',
#        'pancreatic alpha cell', 'pancreatic beta cell',
#        'pancreatic delta cell', 'pancreatic ductal cell',
#        'pancreatic pp cell', 'pancreatic stellate cell',
#        'pancreatic stellate cell activated',
#        'pancreatic stellate cell quiescent', 'plasma cell', 't cell'],
#       dtype='<U34')

# %% [markdown]
# ### Transfer cell type labels from this model to the query dataset using [celltypist.annotate](https://celltypist.readthedocs.io/en/latest/celltypist.annotate.html).

# %%
predictions = celltypist.annotate(adata, custom_model, majority_voting = True)

# %% [markdown]
# By default (`majority_voting = False`), CellTypist will infer the identity of each query cell independently. This leads to raw predicted cell type labels, and usually finishes within seconds or minutes depending on the size of the query data. You can also turn on the majority-voting classifier (`majority_voting = True`), which refines cell identities within local subclusters after an over-clustering approach at the cost of increased runtime.

# %% [markdown]
# The results include both predicted cell type labels (`predicted_labels`), over-clustering result (`over_clustering`), and predicted labels after majority voting in local subclusters (`majority_voting`). Note in the `predicted_labels`, each query cell gets its inferred label by choosing the most probable cell type among all possible cell types in the given model.

# %%
predictions.predicted_labels
# Out:
#                                          predicted_labels over_clustering  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1     myeloid cell               0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1     myeloid cell               2
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1     myeloid cell               3
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1     myeloid cell               5
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1     myeloid cell               8
# ...                                                   ...             ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1     myeloid cell              44
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1     myeloid cell              77
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1     myeloid cell              11
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1     myeloid cell              25
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1     myeloid cell              30
#
#                                          majority_voting
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1    myeloid cell
# ...                                                  ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1    myeloid cell
#
# [10732 rows x 3 columns]

# %% [markdown]
# ### Transform the prediction result into an `AnnData`.

# %%
# Get an `AnnData` with predicted labels embedded into the cell metadata columns.
adata = predictions.to_adata()

# %% [markdown]
# Compared to `adata`, the new `adata` has additional prediction information in `adata.obs` (`predicted_labels`, `over_clustering`, `majority_voting` and `conf_score`). Of note, all these columns can be prefixed with a specific string by setting `prefix` in [to_adata](https://celltypist.readthedocs.io/en/latest/celltypist.classifier.AnnotationResult.html#celltypist.classifier.AnnotationResult.to_adata).

# %%
adata.obs
# Out:
#                                                  patient  n_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1  PA04_AdjNormal     1404
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1  PA04_AdjNormal     4265
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1  PA04_AdjNormal     1621
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1  PA04_AdjNormal     1174
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1  PA04_AdjNormal     1346
# ...                                                  ...      ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1  PA04_AdjNormal     1161
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1  PA04_AdjNormal     1557
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1  PA04_AdjNormal     1471
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1  PA04_AdjNormal     1356
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1  PA04_AdjNormal     1107
#
#                                           n_genes_by_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1               1404
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1               4265
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1               1621
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1               1174
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1               1346
# ...                                                     ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1               1161
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1               1557
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1               1471
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1               1356
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1               1107
#
#                                           log1p_n_genes_by_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                 7.247793
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                 8.358432
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                 7.391415
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                 7.069023
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                 7.205635
# ...                                                           ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                 7.057898
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                 7.351158
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                 7.294377
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                 7.213032
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                 7.010312
#
#                                           total_counts  log1p_total_counts  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1        2724.0            7.910223
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1       16713.0            9.724002
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1        3903.0            8.269757
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1        2438.0            7.799344
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1        3113.0            8.043663
# ...                                                ...                 ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1        2197.0            7.695303
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1        4046.0            8.305731
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1        3433.0            8.141481
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1        2836.0            7.950502
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1        2141.0            7.669495
#
#                                           pct_counts_in_top_50_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                   29.405286
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                   34.045354
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                   36.100436
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                   34.126333
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                   38.997751
# ...                                                              ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                   32.817478
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                   40.434998
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                   36.061754
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                   33.921016
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                   33.395610
#
#                                           pct_counts_in_top_100_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    38.362702
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    43.020403
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    45.785293
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    44.134537
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    47.414070
# ...                                                               ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    42.239417
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    49.728127
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    45.674337
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    42.806770
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    43.063989
#
#                                           pct_counts_in_top_200_genes  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    49.118943
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    51.594567
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    55.649500
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    55.168171
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    57.115323
# ...                                                               ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    52.662722
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    58.897677
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    55.840373
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    53.173484
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    53.946754
#
#                                           pct_counts_in_top_500_genes  ...  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    66.813510  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    63.232214  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    71.278504  ...
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    72.354389  ...
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    72.823643  ...
# ...                                                               ...  ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    69.913518  ...
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    73.875433  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    71.715701  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    69.816643  ...
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    71.648762  ...
#
#                                           pct_counts_ribo  total_counts_hb  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1              0.0              0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1              0.0              0.0
# ...                                                   ...              ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1              0.0              0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1              0.0              0.0
#
#                                           log1p_total_counts_hb  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                    0.0
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                    0.0
# ...                                                         ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1                    0.0
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1                    0.0
#
#                                           pct_counts_hb  doublet_score  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1            0.0       0.030018
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1            0.0       0.035706
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1            0.0       0.024561
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1            0.0       0.025276
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1            0.0       0.010101
# ...                                                 ...            ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1            0.0       0.042654
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1            0.0       0.019193
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1            0.0       0.030453
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1            0.0       0.031341
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1            0.0       0.010470
#
#                                           predicted_doublet  predicted_labels  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1              False      myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1              False      myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1              False      myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1              False      myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1              False      myeloid cell
# ...                                                     ...               ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1              False      myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1              False      myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1              False      myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1              False      myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1              False      myeloid cell
#
#                                           over_clustering  majority_voting  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1                0     myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1                2     myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1                3     myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1                5     myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1                8     myeloid cell
# ...                                                   ...              ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1               44     myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1               77     myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1               11     myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1               25     myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1               30     myeloid cell
#
#                                              conf_score
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1  2.702281e-220
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1  5.272627e-224
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1  4.465193e-248
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1  5.598705e-198
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1  2.666319e-242
# ...                                                 ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1  2.308378e-225
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1  3.007997e-205
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1  4.564577e-287
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1  1.116863e-249
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1  7.838072e-213
#
# [10732 rows x 25 columns]

# %% [markdown]
# In addition to this meta information added, the neighborhood graph constructed during over-clustering is also stored in the `adata`
# (If a pre-calculated neighborhood graph is already present in the `AnnData`, this graph construction step will be skipped).
# This graph can be used to derive the cell embeddings, such as the UMAP coordinates.

# %%
sc.tl.umap(adata)

# %% [markdown]
# ### Visualise the prediction results.

# %%
fig, ax = plt.subplots(3,1,figsize = (15,45), constrained_layout=True)

fig.suptitle("Celltypist Annotation UMAP, Legend on Data", x=0.25, y=1.01, horizontalalignment='left', fontsize=25)

ax[0].set_title('Predicted Labels'),
predicted_label_UMAP=sc.pl.umap(adata, color = ['predicted_labels'], legend_loc = 'on data',ax=ax[0], show=False) 

ax[1].set_title('Majority Voting'),
majority_vote_UMAP=sc.pl.umap(adata, color = ['majority_voting'], palette=sc.pl.palettes.default_20, legend_loc = 'on data', ax=ax[1], show=False)
    
ax[2].set_title('Confidence Score'),
conf_score_UMAP=sc.pl.umap(adata, color = ['conf_score'], legend_loc = 'on data', ax=ax[2])

# %%
fig, ax = plt.subplots(2,1,figsize = (15,25), constrained_layout=True)

fig.suptitle("Celltypist Annotation UMAP, Legend on Right", x=0.3, y=1.03, horizontalalignment='left', fontsize=25)

ax[0].set_title('Predicted Labels'),
predicted_label_UMAP=sc.pl.umap(adata, color = ['predicted_labels'], legend_loc = 'right margin',ax=ax[0], show=False) 

ax[1].set_title('Majority Voting'),
majority_vote_UMAP=sc.pl.umap(adata, color = ['majority_voting'], palette=sc.pl.palettes.default_20, legend_loc = 'right margin', ax=ax[1], show=False)

# %% [markdown]
# ### Total occurrence of cell population in all samples (majority voting)

# %%
count_types = besca.tl.count_occurrence(adata, count_variable='majority_voting', add_percentage=False)
print(count_types)
# Out:
#                   Counts
# myeloid cell       10675
# T cell                42
# endothelial cell      15

# %% [markdown]
# ### Total occurrence of cell population per sample (majority voting)

# %%
# unique_sample_names = adata.obs['sample'].unique().tolist()

# for sample in unique_sample_names:
#     # Filter the AnnData object to include only rows with the current sample
#     subset_adata_built_in = adata[adata.obs['sample'] == sample, :]

#     # Count occurrences for the current sample
#     count_types = besca.tl.count_occurrence(subset_adata_built_in, count_variable='majority_voting', add_percentage=False)
#     print(sample)
#     print('-----------')
#     print(count_types)
#     print('-----------')

# %% [markdown]
# ## Examine Hi/Low Neural Invansion Genes of Interest

# %% [markdown]
# #### Here you can plug in the genes of interest associated with neural invasion in your patients and light up the cells expressing those genes

# %%
# REPLACE PLACEHOLDER GENE NAMES HERE WITH GENE SYMBOLS
examine_genes = ['CCL21','VCAM1','CCR7']
subset_ad = adata[:, examine_genes]

subset_ad.var
# Out:
#       gene_ids    feature_types  n_cells     mt   ribo     hb  \
# CCL21    CCL21  Gene Expression       73  False  False  False
# VCAM1    VCAM1  Gene Expression      411  False  False  False
# CCR7      CCR7  Gene Expression    10847  False  False  False
#
#        n_cells_by_counts  mean_counts  log1p_mean_counts  \
# CCL21                 73     0.042708           0.041821
# VCAM1                411     0.033768           0.033210
# CCR7               10847     1.010838           0.698551
#
#        pct_dropout_by_counts  total_counts  log1p_total_counts
# CCL21              99.776512        1395.0            7.241366
# VCAM1              98.741734        1103.0            7.006695
# CCR7               66.792187       33018.0           10.404839

# %%
subset_df = pd.DataFrame(subset_ad.X.toarray(), index=subset_ad.obs_names, columns=examine_genes)
subset_df
# Out:
#                                           CCL21  VCAM1      CCR7
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1    0.0    0.0  1.811389
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1    0.0    0.0  0.348655
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1    0.0    0.0  0.638247
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1    0.0    0.0  0.751331
# ...                                         ...    ...       ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1    0.0    0.0  2.189813
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1    0.0    0.0  2.498959
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1    0.0    0.0  0.000000
#
# [10732 rows x 3 columns]

# %%
## Create columns for the genes of interest

## Add cell type annotation
ad_df_w_annot = sc.get.obs_df(subset_ad, examine_genes + ['predicted_labels','majority_voting'], use_raw=False)
## Display the table with annotation
ad_df_w_annot
# Out:
#                                           CCL21  VCAM1      CCR7  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1    0.0    0.0  1.811389
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1    0.0    0.0  0.348655
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1    0.0    0.0  0.638247
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1    0.0    0.0  0.751331
# ...                                         ...    ...       ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1    0.0    0.0  2.189813
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1    0.0    0.0  2.498959
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1    0.0    0.0  0.000000
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1    0.0    0.0  0.000000
#
#                                          predicted_labels majority_voting
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCTCAGA-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1     myeloid cell    myeloid cell
# ...                                                   ...             ...
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCGGCATCG-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTCAACTT-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTTGCAAG-1     myeloid cell    myeloid cell
#
# [10732 rows x 5 columns]

# %%
# Step 1: Create a dictionary of boolean Series (True if gene expression > 0)
nonzero_dict = {gene: (ad_df_w_annot[gene] > 0) for gene in examine_genes}

# Step 2: Combine all Series using logical AND to get cells expressing all genes
all_nonzero = reduce(operator.or_, nonzero_dict.values())

# Step 3: Convert the combined boolean Series to a DataFrame
df_genes_bool = all_nonzero.to_frame(name='NI_Genes')

# Step 4: Convert each gene's boolean Series into a DataFrame with '_bool' suffix
gene_bool_dfs = {
    f"df_{gene}_bool": series.to_frame(name=f"{gene}_bool")
    for gene, series in nonzero_dict.items()
}


# Step 5: Subset the original dataframe to get rows where all genes are expressed
ad_ni = ad_df_w_annot.loc[all_nonzero, :]

# %%
## List cell barcodes that pass the TRUE check where all Neural-Invasion (ni)-associated genes are expressed
ad_ni
# Out:
#                                           CCL21  VCAM1      CCR7  \
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1    0.0    0.0  1.811389
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1    0.0    0.0  0.348655
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1    0.0    0.0  0.638247
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1    0.0    0.0  0.751331
# PDAC04-Normal-GEX_out_AAACCTGCAAGCGATG-1    0.0    0.0  0.815701
# ...                                         ...    ...       ...
# PDAC04-Normal-GEX_out_TTTGTCACAAGTAATG-1    0.0    0.0  2.264750
# PDAC04-Normal-GEX_out_TTTGTCACAGTACACT-1    0.0    0.0  2.519643
# PDAC04-Normal-GEX_out_TTTGTCATCATGCATG-1    0.0    0.0  1.185325
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1    0.0    0.0  2.189813
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1    0.0    0.0  2.498959
#
#                                          predicted_labels majority_voting
# PDAC04-Normal-GEX_out_AAACCTGAGCTGTTCA-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGAGTACC-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGAGGCCATAG-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCCCAC-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_AAACCTGCAAGCGATG-1     myeloid cell    myeloid cell
# ...                                                   ...             ...
# PDAC04-Normal-GEX_out_TTTGTCACAAGTAATG-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCACAGTACACT-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCATGCATG-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCGATCCCT-1     myeloid cell    myeloid cell
# PDAC04-Normal-GEX_out_TTTGTCATCTAACTTC-1     myeloid cell    myeloid cell
#
# [5921 rows x 5 columns]

# %%
# Subset table "NettaGenes" containing cells expressing all genes of interest
adata.obs['NI_Genes'] = all_nonzero
adata.obs['NI_Genes'] = adata.obs['NI_Genes'].astype(str).astype('category')

# Create subplots with specific size
fig, ax = plt.subplots(2, 1, figsize=(8, 15), constrained_layout=True)

# Set the title of the entire figure
fig.suptitle("Cells Expressing NI_Genes", x=0.22, y=1.02, horizontalalignment='left', fontsize=12)

# Plot UMAP on the first axis (highlight cells with legend on the right)
ax[0].set_title('Highlight Cells, Legend on Right')
on_right_UMAP = sc.pl.umap(
    adata, 
    color='NI_Genes', 
    legend_loc='on data', 
    title='Highlight Cells, Annotation on Data', 
    frameon=True, 
    palette={"False": "#D3D3D3", "True": "green"}, 
    ax=ax[0], 
    show=False
)

# Plot UMAP on the second axis (highlight cells with legend on the margin)
ax[1].set_title('Highlight Cells on Data')
on_data_UMAP = sc.pl.umap(
    adata, 
    color='NI_Genes', 
    legend_loc='right margin', 
    title='Highlight Cells, Annotation in Legend', 
    frameon=True, 
    ax=ax[1], 
    show=False
)

# %% [markdown]
# ## Celltypist Predicted Labels to Majority Voting Dotplot

# %% [markdown]
# Actually, you may not need to explicitly convert `predictions` output by `celltypist.annotate` into an `AnnData` as above. A more useful way is to use the visualisation function [celltypist.dotplot](https://celltypist.readthedocs.io/en/latest/celltypist.dotplot.html), which quantitatively compares the CellTypist prediction result (e.g. `majority_voting` here) with the cell types pre-defined in the `AnnData` (here `cell_type`). You can also change the value of `use_as_prediction` to `predicted_labels` to compare the raw prediction result with the pre-defined cell types.

# %% [markdown]
# For each pre-defined cell type (each column from the dot plot), this plot shows how it can be 'decomposed' into different cell types predicted by CellTypist (rows).

# %%
celltypist.dotplot(predictions, use_as_reference = 'predicted_labels', use_as_prediction = 'majority_voting')

# %% [markdown]
# ## Examine expression of cell type-driving genes

# %% [markdown]
# Each model can be examined in terms of the driving genes for each cell type. Pick a cell type from the model:

# %%
custom_model.cell_types
# Out:
# array(['B cell', 'Mast cell', 'NK cell', 'T cell', 'b cell',
#        'endothelial cell', 'fibroblast', 'mast cell', 'myeloid cell',
#        'pancreatic acinar cell', 'pancreatic acing cell',
#        'pancreatic alpha cell', 'pancreatic beta cell',
#        'pancreatic delta cell', 'pancreatic ductal cell',
#        'pancreatic pp cell', 'pancreatic stellate cell',
#        'pancreatic stellate cell activated',
#        'pancreatic stellate cell quiescent', 'plasma cell', 't cell'],
#       dtype='<U34')

# %% [markdown]
# Extract the top 10 driving genes of `<CELLTYPE OF INTEREST>` using the [extract_top_markers](https://celltypist.readthedocs.io/en/latest/celltypist.models.Model.html#celltypist.models.Model.extract_top_markers) method.

# %%
## REPLACE 'CELLTYPE OF INTEREST' with a Cell Type above 
top_20_genes = custom_model.extract_top_markers("T cell", 10)
top_20_genes
# Out:
# array(['CD3G', 'IL7R', 'CD3E', 'CD3D', 'TRAC', 'CD2', 'CD8A', 'GZMA',
#        'IKZF3', 'CD8B'], dtype=object)

# %%
# Check expression of the twelve genes in the query set.
# Here we use `majority_voting` from CellTypist as the cell type labels for this dataset.
genes_present = [gene for gene in top_20_genes if gene in adata.var_names]

# Select the top 10 from those present
top_10_genes_present = genes_present[:10]

# Create violin plot of expression by majority voting labels
sc.pl.violin(adata, top_10_genes_present, groupby='majority_voting', rotation=90)
