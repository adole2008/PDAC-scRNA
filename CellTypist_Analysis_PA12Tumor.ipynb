# %% [markdown]
# # Using CellTypist for cell type classification
# This notebook showcases the cell type classification for scRNA-seq query data by retrieving the most likely cell type labels from the built-in CellTypist models.

# %% [markdown]
# ## Install CellTypist

# %%
import sys
import subprocess
import warnings

# Suppress specific warnings
# from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
# warnings.filterwarnings("ignore", category=NumbaDeprecationWarning)
# warnings.filterwarnings("ignore", category=NumbaPendingDeprecationWarning)

# List of required packages
required_packages = [
    "anndata",
    "scanpy",
    "besca",
    "matplotlib",
    "pandas",
    "celltypist"
]

# Install packages quietly
for package in required_packages:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", package, "--quiet"],
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL
    )

# %%
# %%capture --no-display
import anndata
import scanpy as sc
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
import besca
import matplotlib.pyplot as plt
import pandas as pd
from functools import reduce
import operator
import celltypist
from celltypist import models

# %% [markdown]
# ## Load a scRNA-seq dataset .h5ad file

# %%
##  REPLACE <SAMPLE MATRIX FILE> with the filename of your matrix
adata = sc.read_h5ad('datasets/PA12_Tumor.h5ad')

# %% [markdown]
# ## Assign cell type labels using a CellTypist built-in model
# In this section, we show the procedure of transferring cell type labels from a custom model to the query dataset.

# %%
## REPLACE <YOUR MODEL FILENAME> with the PKL file you made
custom_model = models.Model.load(model = 'UCSC_human_pancreas_model.pkl')

# %% [markdown]
# Show the built-in model meta information:

# %%
custom_model
# Out:
# CellTypist model with 21 cell types and 51863 features
#     date: 2025-08-10 11:08:01.514089
#     cell types: B cell, Mast cell, ..., t cell
#     features: WASH7P, MIR6859-1, ..., MT-TP

# %% [markdown]
# #### This model contains 15 cell states.

# %%
custom_model.cell_types
# Out:
# array(['B cell', 'Mast cell', 'NK cell', 'T cell', 'b cell',
#        'endothelial cell', 'fibroblast', 'mast cell', 'myeloid cell',
#        'pancreatic acinar cell', 'pancreatic acing cell',
#        'pancreatic alpha cell', 'pancreatic beta cell',
#        'pancreatic delta cell', 'pancreatic ductal cell',
#        'pancreatic pp cell', 'pancreatic stellate cell',
#        'pancreatic stellate cell activated',
#        'pancreatic stellate cell quiescent', 'plasma cell', 't cell'],
#       dtype='<U34')

# %% [markdown]
# ### Transfer cell type labels from this model to the query dataset using [celltypist.annotate](https://celltypist.readthedocs.io/en/latest/celltypist.annotate.html).

# %%
predictions = celltypist.annotate(adata, custom_model, majority_voting = True)

# %% [markdown]
# By default (`majority_voting = False`), CellTypist will infer the identity of each query cell independently. This leads to raw predicted cell type labels, and usually finishes within seconds or minutes depending on the size of the query data. You can also turn on the majority-voting classifier (`majority_voting = True`), which refines cell identities within local subclusters after an over-clustering approach at the cost of increased runtime.

# %% [markdown]
# The results include both predicted cell type labels (`predicted_labels`), over-clustering result (`over_clustering`), and predicted labels after majority voting in local subclusters (`majority_voting`). Note in the `predicted_labels`, each query cell gets its inferred label by choosing the most probable cell type among all possible cell types in the given model.

# %%
predictions.predicted_labels
# Out:
#                                                predicted_labels  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell
# ...                                                         ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell
#
#                                         over_clustering  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1               0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1               2
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1               3
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1               4
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1               5
# ...                                                 ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1              91
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1              50
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1              19
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1              28
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1               8
#
#                                                 majority_voting
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell
# ...                                                         ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell
#
# [5879 rows x 3 columns]

# %% [markdown]
# ### Transform the prediction result into an `AnnData`.

# %%
# Get an `AnnData` with predicted labels embedded into the cell metadata columns.
adata = predictions.to_adata()

# %% [markdown]
# Compared to `adata`, the new `adata` has additional prediction information in `adata.obs` (`predicted_labels`, `over_clustering`, `majority_voting` and `conf_score`). Of note, all these columns can be prefixed with a specific string by setting `prefix` in [to_adata](https://celltypist.readthedocs.io/en/latest/celltypist.classifier.AnnotationResult.html#celltypist.classifier.AnnotationResult.to_adata).

# %%
adata.obs
# Out:
#                                             patient  n_genes  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1  PA12_Tumor     3402
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1  PA12_Tumor     1315
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1  PA12_Tumor     2051
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1  PA12_Tumor     2800
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1  PA12_Tumor     1720
# ...                                             ...      ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  PA12_Tumor     3227
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1  PA12_Tumor     2465
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1  PA12_Tumor     1869
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1  PA12_Tumor     2191
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1  PA12_Tumor     2467
#
#                                          n_genes_by_counts  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1               3402
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1               1315
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1               2050
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1               2800
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1               1720
# ...                                                    ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1               3227
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1               2465
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1               1869
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1               2191
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1               2467
#
#                                          log1p_n_genes_by_counts  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                 8.132413
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                 7.182352
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                 7.626083
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                 7.937732
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                 7.450661
# ...                                                          ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                 8.079618
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                 7.810353
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                 7.533694
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                 7.692570
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                 7.811163
#
#                                          total_counts  log1p_total_counts  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1       10297.0            9.239705
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1        3191.0            8.068403
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1        4390.0            8.387312
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1        7992.0            8.986321
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1        3759.0            8.232174
# ...                                               ...                 ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1        6796.0            8.824237
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1        6016.0            8.702344
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1        3828.0            8.250359
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1        4953.0            8.507951
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1        6388.0            8.762333
#
#                                          pct_counts_in_top_50_genes  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                   30.824512
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                   39.360702
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                   30.113895
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                   36.286286
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                   33.306731
# ...                                                             ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                   21.350795
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                   32.081117
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                   30.642633
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                   30.244296
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                   31.825297
#
#                                          pct_counts_in_top_100_genes  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                    38.710304
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                    48.511438
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                    36.765376
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                    44.094094
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                    41.260974
# ...                                                              ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                    28.090053
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                    39.245346
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                    37.957158
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                    37.754896
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                    39.887289
#
#                                          pct_counts_in_top_200_genes  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                    47.343887
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                    58.759010
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                    45.489749
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                    51.839339
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                    50.332535
# ...                                                              ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                    36.109476
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                    47.623005
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                    46.682341
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                    46.396124
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                    48.935504
#
#                                          pct_counts_in_top_500_genes  ...  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                    60.716714  ...
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                    74.459417  ...
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                    61.230068  ...
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                    64.789790  ...
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                    67.411546  ...
# ...                                                              ...  ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                    50.941730  ...
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                    61.785239  ...
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                    63.296761  ...
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                    61.255805  ...
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                    63.212273  ...
#
#                                          pct_counts_ribo  total_counts_hb  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1              0.0              0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1              0.0              0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1              0.0              0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1              0.0              0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1              0.0              0.0
# ...                                                  ...              ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1              0.0              0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1              0.0              0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1              0.0              0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1              0.0              0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1              0.0              0.0
#
#                                          log1p_total_counts_hb  pct_counts_hb  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                    0.0            0.0
# ...                                                        ...            ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                    0.0            0.0
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                    0.0            0.0
#
#                                          doublet_score  predicted_doublet  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1       0.086630              False
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1       0.020536              False
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1       0.057037              False
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1       0.063221              False
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1       0.017758              False
# ...                                                ...                ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1       0.050650              False
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1       0.024534              False
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1       0.122691              False
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1       0.057037              False
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1       0.052669              False
#
#                                                predicted_labels  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell
# ...                                                         ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell
#
#                                          over_clustering  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1                0
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1                2
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1                3
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1                4
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                5
# ...                                                  ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1               91
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1               50
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1               19
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1               28
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1                8
#
#                                                 majority_voting     conf_score
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell  1.557145e-307
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell  4.357968e-180
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell  2.354302e-205
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell  1.106501e-228
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell  5.461820e-168
# ...                                                         ...            ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell   1.000000e+00
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell  4.208205e-145
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell  4.128352e-198
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1            myeloid cell  8.749328e-156
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell  1.716559e-198
#
# [5879 rows x 25 columns]

# %% [markdown]
# In addition to this meta information added, the neighborhood graph constructed during over-clustering is also stored in the `adata`
# (If a pre-calculated neighborhood graph is already present in the `AnnData`, this graph construction step will be skipped).
# This graph can be used to derive the cell embeddings, such as the UMAP coordinates.

# %%
sc.tl.umap(adata)

# %% [markdown]
# ### Visualise the prediction results.

# %%
fig, ax = plt.subplots(3,1,figsize = (15,45), constrained_layout=True)

fig.suptitle("Celltypist Annotation UMAP, Legend on Data", x=0.25, y=1.01, horizontalalignment='left', fontsize=25)

ax[0].set_title('Predicted Labels'),
predicted_label_UMAP=sc.pl.umap(adata, color = ['predicted_labels'], legend_loc = 'on data',ax=ax[0], show=False) 

ax[1].set_title('Majority Voting'),
majority_vote_UMAP=sc.pl.umap(adata, color = ['majority_voting'], palette=sc.pl.palettes.default_20, legend_loc = 'on data', ax=ax[1], show=False)
    
ax[2].set_title('Confidence Score'),
conf_score_UMAP=sc.pl.umap(adata, color = ['conf_score'], legend_loc = 'on data', ax=ax[2])

# %%
fig, ax = plt.subplots(2,1,figsize = (15,25), constrained_layout=True)

fig.suptitle("Celltypist Annotation UMAP, Legend on Right", x=0.3, y=1.03, horizontalalignment='left', fontsize=25)

ax[0].set_title('Predicted Labels'),
predicted_label_UMAP=sc.pl.umap(adata, color = ['predicted_labels'], legend_loc = 'right margin',ax=ax[0], show=False) 

ax[1].set_title('Majority Voting'),
majority_vote_UMAP=sc.pl.umap(adata, color = ['majority_voting'], palette=sc.pl.palettes.default_20, legend_loc = 'right margin', ax=ax[1], show=False)

# %% [markdown]
# ### Total occurrence of cell population in all samples (majority voting)

# %%
count_types = besca.tl.count_occurrence(adata, count_variable='majority_voting', add_percentage=False)
print(count_types)
# Out:
#                         Counts
# myeloid cell              4645
# T cell                     850
# endothelial cell           214
# pancreatic ductal cell     147
# pancreatic acinar cell      23

# %% [markdown]
# ### Total occurrence of cell population per sample (majority voting)

# %%
# unique_sample_names = adata.obs['sample'].unique().tolist()

# for sample in unique_sample_names:
#     # Filter the AnnData object to include only rows with the current sample
#     subset_adata_built_in = adata[adata.obs['sample'] == sample, :]

#     # Count occurrences for the current sample
#     count_types = besca.tl.count_occurrence(subset_adata_built_in, count_variable='majority_voting', add_percentage=False)
#     print(sample)
#     print('-----------')
#     print(count_types)
#     print('-----------')

# NOTE: I already filtered in previous step for 1 sample per h5ad file, so no need to run this cell

# %% [markdown]
# ## Examine Genes of Interest

# %% [markdown]
# #### Here you can plug in the genes of interest associated with TLS in your patient tissue and light up the cells expressing those genes

# %%
# REPLACE PLACEHOLDER GENE NAMES HERE WITH GENE SYMBOLS
examine_genes = ['CCL21','VCAM1','CCR7']
subset_ad = adata[:, examine_genes]

subset_ad.var
# Out:
#       gene_ids    feature_types  n_cells     mt   ribo     hb  \
# CCL21    CCL21  Gene Expression       62  False  False  False
# VCAM1    VCAM1  Gene Expression      356  False  False  False
# CCR7      CCR7  Gene Expression     4947  False  False  False
#
#        n_cells_by_counts  mean_counts  log1p_mean_counts  \
# CCL21                 62     0.056893           0.055334
# VCAM1                356     0.045542           0.044535
# CCR7                4947     0.573142           0.453075
#
#        pct_dropout_by_counts  total_counts  log1p_total_counts
# CCL21              99.716221        1243.0            7.126087
# VCAM1              98.370560         995.0            6.903747
# CCR7               77.357195       12522.0            9.435322

# %%
subset_df = pd.DataFrame(subset_ad.X.toarray(), index=subset_ad.obs_names, columns=examine_genes)
subset_df
# Out:
#                                             CCL21     VCAM1     CCR7
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1  0.916232  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1  0.000000  0.000000  0.39414
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1  0.000000  0.000000  0.00000
# ...                                           ...       ...      ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1  0.000000  0.825743  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1  0.000000  0.000000  0.00000
#
# [5879 rows x 3 columns]

# %%
## Create columns for the genes of interest

## Add cell type annotation
ad_df_w_annot = sc.get.obs_df(subset_ad, examine_genes + ['predicted_labels','majority_voting'], use_raw=False)
## Display the table with annotation
ad_df_w_annot
# Out:
#                                             CCL21     VCAM1     CCR7  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1  0.916232  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1  0.000000  0.000000  0.39414
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1  0.000000  0.000000  0.00000
# ...                                           ...       ...      ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1  0.000000  0.825743  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1  0.000000  0.000000  0.00000
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1  0.000000  0.000000  0.00000
#
#                                                predicted_labels  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell
# ...                                                         ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell
#
#                                                 majority_voting
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTAGCCA-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTCATCT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1            myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGTGTACCT-1                  T cell
# ...                                                         ...
# PDAC12-Tumor-GEX_out_TTTGTCAGTGTCGCTG-1  pancreatic ductal cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1                  T cell
# PDAC12-Tumor-GEX_out_TTTGTCATCCCTTGTG-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTACCTGC-1            myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCTCGAGTA-1            myeloid cell
#
# [5879 rows x 5 columns]

# %%
# Step 1: Create a dictionary of boolean Series (True if gene expression > 0)
nonzero_dict = {gene: (ad_df_w_annot[gene] > 0) for gene in examine_genes}

# Step 2: Combine all Series using logical OR to get cells expressing at least 1 gene
all_nonzero = reduce(operator.or_, nonzero_dict.values())

# Step 3: Convert the combined boolean Series to a DataFrame
df_genes_bool = all_nonzero.to_frame(name='NI_Genes')

# Step 4: Convert each gene's boolean Series into a DataFrame with '_bool' suffix
gene_bool_dfs = {
    f"df_{gene}_bool": series.to_frame(name=f"{gene}_bool")
    for gene, series in nonzero_dict.items()
}


# Step 5: Subset the original dataframe to get rows where all genes are expressed
ad_ni = ad_df_w_annot.loc[all_nonzero, :]

# %%
## List cell barcodes that pass the TRUE check where all TLS-associated genes are expressed
ad_ni
# Out:
#                                             CCL21     VCAM1      CCR7  \
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1  0.916232  0.000000  0.000000
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1  0.000000  0.000000  0.394140
# PDAC12-Tumor-GEX_out_AAACCTGCACACGCTG-1  0.000000  0.000000  1.260557
# PDAC12-Tumor-GEX_out_AAACCTGCATAAGACA-1  0.000000  0.332654  0.000000
# PDAC12-Tumor-GEX_out_AAACCTGGTGTCTGAT-1  0.000000  0.000000  0.308277
# ...                                           ...       ...       ...
# PDAC12-Tumor-GEX_out_TTTGTCACAACACCTA-1  0.000000  0.000000  0.763940
# PDAC12-Tumor-GEX_out_TTTGTCACACAACGCC-1  0.000000  0.000000  1.989611
# PDAC12-Tumor-GEX_out_TTTGTCAGTACTCGCG-1  0.000000  0.000000  0.931474
# PDAC12-Tumor-GEX_out_TTTGTCAGTAGCTGCC-1  0.000000  0.000000  0.594236
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1  0.000000  0.825743  0.000000
#
#                                          predicted_labels majority_voting
# PDAC12-Tumor-GEX_out_AAACCTGAGCGTTCCG-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGAGGTGTGGT-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGCACACGCTG-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGCATAAGACA-1  endothelial cell    myeloid cell
# PDAC12-Tumor-GEX_out_AAACCTGGTGTCTGAT-1      myeloid cell    myeloid cell
# ...                                                   ...             ...
# PDAC12-Tumor-GEX_out_TTTGTCACAACACCTA-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCACACAACGCC-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCAGTACTCGCG-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCAGTAGCTGCC-1      myeloid cell    myeloid cell
# PDAC12-Tumor-GEX_out_TTTGTCATCATCGATG-1            T cell          T cell
#
# [1646 rows x 5 columns]

# %%
# Subset table "NettaGenes" containing cells expressing all genes of interest
adata.obs['NI_Genes'] = all_nonzero
adata.obs['NI_Genes'] = adata.obs['NI_Genes'].astype(str).astype('category')

# Create subplots with specific size
fig, ax = plt.subplots(2, 1, figsize=(8, 15), constrained_layout=True)

# Set the title of the entire figure
fig.suptitle("Cells Expressing Genes Associated with TLS formation (PA12 Tumor)", x=0.22, y=1.02, horizontalalignment='left', fontsize=12)

# Plot UMAP on the first axis (highlight cells with legend on the right)
ax[0].set_title('Highlight Cells, Legend on Right')
on_right_UMAP = sc.pl.umap(
    adata, 
    color='NI_Genes', 
    legend_loc='on data', 
    title='Highlight Cells, Annotation on Data', 
    frameon=True, 
    palette={"False": "#D3D3D3", "True": "green"}, 
    ax=ax[0], 
    show=False
)

# Plot UMAP on the second axis (highlight cells with legend on the margin)
ax[1].set_title('Highlight Cells on Data')
on_data_UMAP = sc.pl.umap(
    adata, 
    color='NI_Genes', 
    legend_loc='right margin', 
    title='Highlight Cells, Annotation in Legend', 
    frameon=True, 
    ax=ax[1], 
    show=False
)

# %% [markdown]
# ## Celltypist Predicted Labels to Majority Voting Dotplot

# %% [markdown]
# Actually, you may not need to explicitly convert `predictions` output by `celltypist.annotate` into an `AnnData` as above. A more useful way is to use the visualisation function [celltypist.dotplot](https://celltypist.readthedocs.io/en/latest/celltypist.dotplot.html), which quantitatively compares the CellTypist prediction result (e.g. `majority_voting` here) with the cell types pre-defined in the `AnnData` (here `cell_type`). You can also change the value of `use_as_prediction` to `predicted_labels` to compare the raw prediction result with the pre-defined cell types.

# %% [markdown]
# For each pre-defined cell type (each column from the dot plot), this plot shows how it can be 'decomposed' into different cell types predicted by CellTypist (rows).

# %%
celltypist.dotplot(predictions, use_as_reference = 'predicted_labels', use_as_prediction = 'majority_voting')

# %% [markdown]
# ## Examine expression of cell type-driving genes

# %% [markdown]
# Each model can be examined in terms of the driving genes for each cell type. Pick a cell type from the model:

# %%
custom_model.cell_types
# Out:
# array(['B cell', 'Mast cell', 'NK cell', 'T cell', 'b cell',
#        'endothelial cell', 'fibroblast', 'mast cell', 'myeloid cell',
#        'pancreatic acinar cell', 'pancreatic acing cell',
#        'pancreatic alpha cell', 'pancreatic beta cell',
#        'pancreatic delta cell', 'pancreatic ductal cell',
#        'pancreatic pp cell', 'pancreatic stellate cell',
#        'pancreatic stellate cell activated',
#        'pancreatic stellate cell quiescent', 'plasma cell', 't cell'],
#       dtype='<U34')

# %% [markdown]
# Extract the top 10 driving genes of `<CELLTYPE OF INTEREST>` using the [extract_top_markers](https://celltypist.readthedocs.io/en/latest/celltypist.models.Model.html#celltypist.models.Model.extract_top_markers) method.

# %%
## REPLACE 'CELLTYPE OF INTEREST' with a Cell Type above 
top_20_genes = custom_model.extract_top_markers("T cell", 20)
top_20_genes
# Out:
# array(['CD3G', 'IL7R', 'CD3E', 'CD3D', 'TRAC', 'CD2', 'CD8A', 'GZMA',
#        'IKZF3', 'CD8B', 'BCL11B', 'CCL5', 'CD96', 'TRBC2', 'KLRC1',
#        'IKZF1', 'LINC01871', 'CXCR6', 'RHOH', 'CXCR3'], dtype=object)

# %%
# Check expression of the twelve genes in the query set.
# Here we use `majority_voting` from CellTypist as the cell type labels for this dataset.
genes_present = [gene for gene in top_20_genes if gene in adata.var_names]

# Select the top 10 from those present
top_10_genes_present = genes_present[:10]

# Create violin plot of expression by majority voting labels
sc.pl.violin(adata, top_10_genes_present, groupby='majority_voting', rotation=90)
